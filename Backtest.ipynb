# %%
# 导入必要的库
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook
import matplotlib.dates as mdates
import numpy as np
import liquidity
import GraphBacktest
import charts

# 网络选择: 1=以太坊主网, 2=Arbitrum, 3=Optimism
network = 1  # Ethereum 主网

# 各种池子地址
Adress = "0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640"  # USDC/ETH 主网池子

# 回测起始时间戳 (2023-01-01)
startfrom = 1672531200

# 从Graph获取池子历史数据
dpd = GraphBacktest.graph(network, Adress, startfrom)

# 获取代币精度信息       
decimal0 = dpd.iloc[0]['pool.token0.decimals']  # token0 精度
decimal1 = dpd.iloc[0]['pool.token1.decimals']  # token1 精度
decimal = decimal1-decimal0  # 精度差值

# 计算全局手续费增长
# 将128位定点数转换为标准数值，并根据代币精度进行调整
dpd['fg0'] = ((dpd['feeGrowthGlobal0X128'])/(2**128))/(10**decimal0)
dpd['fg1'] = ((dpd['feeGrowthGlobal1X128'])/(2**128))/(10**decimal1)

# 设置流动性价格区间参数
mini = 1500  # 最小价格边界
maxi = 1700  # 最大价格边界
target = 10000  # 目标流动性价值
base = 0  # 基准代币选择: 0=token0, 1=token1

# 计算每期的手续费增长
dpd['fg0shift'] = dpd['fg0'].shift(-1)  # 下一期的手续费
dpd['fg1shift'] = dpd['fg1'].shift(-1)
dpd['fee0token'] = dpd['fg0']-dpd['fg0shift']  # 当期手续费增长
dpd['fee1token'] = dpd['fg1']-dpd['fg1shift']

# 计算流动性相关参数
SMIN = np.sqrt(mini * 10 ** (decimal))   # 最小价格的平方根
SMAX = np.sqrt(maxi * 10 ** (decimal))   # 最大价格的平方根

# 根据基准代币计算初始价格
if base == 0:
    sqrt0 = np.sqrt(dpd['close'].iloc[-1] * 10 ** (decimal))
    dpd['price0'] = dpd['close']
else:
    sqrt0 = np.sqrt(1/dpd['close'].iloc[-1] * 10 ** (decimal))
    dpd['price0'] = 1/dpd['close']

# 根据当前价格位置计算所需的token数量
if sqrt0 > SMIN and sqrt0 < SMAX:
    # 价格在区间内
    deltaL = target / ((sqrt0 - SMIN) + (((1 / sqrt0) - (1 / SMAX)) * (dpd['price0'].iloc[-1] * 10 ** (decimal))))
    amount1 = deltaL * (sqrt0-SMIN)
    amount0 = deltaL * ((1/sqrt0)-(1/SMAX)) * 10 ** (decimal)
elif sqrt0 < SMIN:
    # 价格低于区间
    deltaL = target / (((1 / SMIN) - (1 / SMAX)) * (dpd['price0'].iloc[-1]))
    amount1 = 0
    amount0 = deltaL * ((1/SMIN) - (1/SMAX))
else:
    # 价格高于区间
    deltaL = target / (SMAX-SMIN)
    amount1 = deltaL * (SMAX-SMIN)
    amount0 = 0

print("Amounts:", amount0, amount1)

# 计算流动性
myliquidity = liquidity.get_liquidity(dpd['price0'].iloc[-1], mini, maxi, amount0, amount1, decimal0, decimal1)
print("OK myliquidity", myliquidity)

# 初始化流动性统计数据
dpd['ActiveLiq'] = 0  # 活跃流动性比例
dpd['amount0'] = 0    # token0 数量
dpd['amount1'] = 0    # token1 数量
dpd['amount0unb'] = 0 # 无限区间 token0 数量
dpd['amount1unb'] = 0 # 无限区间 token1 数量

# 根据基准代币计算每期的流动性状态
if base == 0:  # 如果使用token0作为基准代币
    for i, row in dpd.iterrows():
        # 计算价格区间内的活跃流动性比例
        # 判断当前价格是否与设定的价格区间有重叠
        if dpd['high'].iloc[i] > mini and dpd['low'].iloc[i] < maxi:
            # 计算重叠区间占总价格区间的比例
            # min(maxi,high): 取重叠区间的上界
            # max(low,mini): 取重叠区间的下界
            # 相减得到重叠区间长度，除以总区间长度，转换为百分比
            dpd.iloc[i,dpd.columns.get_loc('ActiveLiq')] = (min(maxi,dpd['high'].iloc[i]) - max(dpd['low'].iloc[i],mini)) / (dpd['high'].iloc[i]-dpd['low'].iloc[i]) * 100
        else:
            # 如果价格完全在区间外，活跃流动性为0
            dpd.iloc[i,dpd.columns.get_loc('ActiveLiq')] = 0
        
        # 计算有限价格区间的token数量
        # 根据当前价格、设定的价格区间和流动性计算应持有的token数量
        amounts = liquidity.get_amounts(dpd['price0'].iloc[i], mini, maxi, myliquidity, decimal0, decimal1)
        dpd.iloc[i,dpd.columns.get_loc('amount0')] = amounts[1]  # token0数量
        dpd.iloc[i,dpd.columns.get_loc('amount1')] = amounts[0]  # token1数量
        
        # 计算无限价格区间的token数量（用于比较基准情况）
        # 1.0001**(-887220)和1.0001**887220是最小和最大可能的价格
        # 相当于在整个价格范围内提供流动性
        amountsunb = liquidity.get_amounts((dpd['price0'].iloc[i]), 1.0001**(-887220), 1.0001**887220, 1, decimal0, decimal1)
        dpd.iloc[i,dpd.columns.get_loc('amount0unb')] = amountsunb[1]  # 无限区间token0数量
        dpd.iloc[i,dpd.columns.get_loc('amount1unb')] = amountsunb[0]  # 无限区间token1数量

# 计算最终的手续费收入
dpd['myfee0'] = dpd['fee0token'] * myliquidity * dpd['ActiveLiq'] / 100  # token0 手续费
dpd['myfee1'] = dpd['fee1token'] * myliquidity * dpd['ActiveLiq'] / 100  # token1 手续费

# 添加基准手续费计算
dpd['feeVbase0'] = dpd['fee0token']  # token0 基准手续费
dpd['feeVbase1'] = dpd['fee1token']  # token1 基准手续费

# 生成图表
a = charts.chart1(dpd, base, myliquidity)
# Out:
# 1672531200
# 正在查询网络: 1
# 使用端点: https://gateway.thegraph.com/api/subgraphs/id/5zvR82QoaXYFyDEKLZ9t6v9adgnptxYpKpSbxtgVENFV
# 正在查询地址: 0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640
# 查询起始时间: 1672531200
# 查询响应: {'poolHourDatas': [{'close': '1628.412083348633521085072187156129', 'feeGrowthGlobal0X128': '3791103120864153156222782210942076', 'feeGrowthGlobal1X128': '1684812538372128835464963670365023578564776', 'high': '1634.307017248466927789551140110433', 'liquidity': '4082386183039074689', 'low': '1614.587860403722199720696215969236', 'periodStartUnix': 1744614000, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLockedUSD': '338150595.6313967780239193399350876'}}, {'close': '1623.364306400092094626814555407329', 'feeGrowthGlobal0X128': '3791010528096817704244810701148483', 'feeGrowthGlobal1X128': '1684761007113861375542880965745428490849045', 'high': '1626.608427596689539388152735366827', 'liquidity': '4083380967738915581', 'low': '1615.435514596956947618399706240719', 'periodStartUnix': 1744610400, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLockedUSD': '338150595.6313967780239193399350876'}}, {'close': '1623.486332410857225057399573347408', 'feeGrowthGlobal0X128': '3790930554163909758336457483404030', 'feeGrowthGlobal1X128': '1684711528509345369995936079599135742786426', 'high': '1638.598231563641719379926282817659', 'liquidity': '4083032627076789271', 'low': '1621.746787706327733711236011651468', 'periodStartUnix': 1744606800, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLockedUSD': '338150595.6313967780239193399350876'}}, {'close': '1636.847020005935097547624254886513', 'feeGrowthGlobal0X128': '3790881173281241789214756112963582', 'feeGrowthGlobal1X128': '1684663965579496808563186077436598921048115', 'high': '1640.432494928942745155325581379337', 'liquidity': '4106872047455576533', 'low': '1628.267869803379610068200293209258', 'periodStartUnix': 1744603200, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLockedUSD': '338150595.6313967780239193399350876'}}, {'close': '1628.662427971961906095010234414346', 'feeGrowthGlobal0X128': '3790798452604297601164745775431454', 'feeGrowthGlobal1X128': '1684623906946306406773798014703310347101080', 'high': '1635.978057769809825326666331519654', 'liquidity': '4070984220679180343', 'low': '1626.653480614091842113605732368103', 'periodStartUnix': 1744599600, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLockedUSD': '338150595.6313967780239193399350876'}}, {'close': '1635.349012820580842210411213701853', 'feeGrowthGlobal0X128': '3790734953416650595312588580174413', 'feeGrowthGlobal1X128': '1684576472458807997489749132499586857818193', 'high': '1656.444940496109433722061646279446', 'liquidity': '4096669309533147970', 'low': '1615.216490470555689044356935905984', 'periodStartUnix': 1744596000, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLockedUSD': '338150595.6313967780239193399350876'}}, {'close': '1615.962674051674771762215996398405', 'feeGrowthGlobal0X128': '3790404454599189573289474465515482', 'feeGrowthGlobal1X128': '1684400542941789915963125860667799560221123', 'high': '1621.145744179962833292996323720075', 'liquidity': '4081380383892121467', 'low': '1609.69217500980582879588583258671', 'periodStartUnix': 1744592400, 'pool': {'token0': {'decimals': '6'}, 'token1': {'decimals': '18'}, 'totalValueLockedToken0': '152726571.217403', 'totalValueLockedToken1': '114207.176577135859591974', 'totalValueLock ...
# 获取到 1000 条数据
# 数据列： ['close', 'feeGrowthGlobal0X128', 'feeGrowthGlobal1X128', 'high', 'liquidity', 'low', 'periodStartUnix', 'pool.token0.decimals', 'pool.token1.decimals', 'pool.totalValueLockedToken0', 'pool.totalValueLockedToken1', 'pool.totalValueLockedUSD']
# Amounts: 0 10000.0
# OK myliquidity 3998044485912537.0
#                feeunb        feeV      feeusd       amountV   ActiveLiq  \
# date
# 2025-03-03   2.132093    0.000000    0.000000  10000.000000    0.000000
# 2025-03-04   4.417728    0.000000    0.000000  10000.000000    0.000000
# 2025-03-05   1.957343    0.000000    0.000000  10000.000000    0.000000
# 2025-03-06   1.849168    0.000000    0.000000  10000.000000    0.000000
# 2025-03-07   2.738168    0.000000    0.000000  10000.000000    0.000000
# 2025-03-08   1.025304    0.000000    0.000000  10000.000000    0.000000
# 2025-03-09   1.739904    0.000000    0.000000  10000.000000    0.000000
# 2025-03-10   4.774520    0.000000    0.000000  10000.000000    0.000000
# 2025-03-11   4.060108    0.000000    0.000000  10000.000000    0.000000
# 2025-03-12   2.288879    0.000000    0.000000  10000.000000    0.000000
# 2025-03-13   1.768534    0.000000    0.000000  10000.000000    0.000000
# 2025-03-14   0.902266    0.000000    0.000000  10000.000000    0.000000
# 2025-03-15   0.381106    0.000000    0.000000  10000.000000    0.000000
# 2025-03-16   0.645617    0.000000    0.000000  10000.000000    0.000000
# 2025-03-17   0.647198    0.000000    0.000000  10000.000000    0.000000
# 2025-03-18   0.682029    0.000000    0.000000  10000.000000    0.000000
# 2025-03-19   1.295038    0.000000    0.000000  10000.000000    0.000000
# 2025-03-20   0.755309    0.000000    0.000000  10000.000000    0.000000
# 2025-03-21   0.549846    0.000000    0.000000  10000.000000    0.000000
# 2025-03-22   0.271145    0.000000    0.000000  10000.000000    0.000000
# 2025-03-23   0.309558    0.000000    0.000000  10000.000000    0.000000
# 2025-03-24   0.824066    0.000000    0.000000  10000.000000    0.000000
# 2025-03-25   0.639181    0.000000    0.000000  10000.000000    0.000000
# 2025-03-26   0.648653    0.000000    0.000000  10000.000000    0.000000
# 2025-03-27   0.490152    0.000000    0.000000  10000.000000    0.000000
# 2025-03-28   1.182670    0.000000    0.000000  10000.000000    0.000000
# 2025-03-29   0.943590    0.000000    0.000000  10000.000000    0.000000
# 2025-03-30   1.003979    0.000000    0.000000  10000.000000    0.000000
# 2025-03-31   1.220462    0.000000    0.000000  10000.000000    0.000000
# 2025-04-01   0.905091    0.000000    0.000000  10000.000000    0.000000
# 2025-04-02   1.654981    0.000000    0.000000  10000.000000    0.000000
# 2025-04-03   1.431643    0.000000    0.000000  10000.000000    0.000000
# 2025-04-04   1.442129    0.000000    0.000000  10000.000000    0.000000
# 2025-04-05   0.468867    0.000000    0.000000  10000.000000    0.000000
# 2025-04-06   7.308128  209.029783  208.688919  10000.000000   26.384922
# 2025-04-07  11.958866  194.084421  193.767929   9755.360065   73.719698
# 2025-04-08   3.981679   54.261561   54.173077   9639.279737   69.268670
# 2025-04-09   6.747285   82.820104   82.685050   9186.311113   29.300764
# 2025-04-10   4.163737  118.093900  117.901324   9958.384434   93.431304
# 2025-04-11   1.756798   57.795664   57.701417   9434.381393  100.000000
# 2025-04-12   1.533526   49.879808   49.798469   9713.413066  100.000000
# 2025-04-13   1.821004   59.295493   59.198800   9951.826038  100.000000
# 2025-04-14   0.681328   22.122826   22.086751   9882.749048  100.000000
#
#                  S1%      unb%   ActiveLiq
# date
# 2025-03-03  0.000000  0.021321    0.000000
# 2025-03-04  0.000000  0.044177    0.000000
# 2025-03-05  0.000000  0.019573    0.000000
# 2025-03-06  0.000000  0.018492    0.000000
# 2025-03-07  0.000000  0.027382    0.000000
# 2025-03-08  0.000000  0.010253    0.000000
# 2025-03-09  0.000000  0.017399    0.000000
# 2025-03-10  0.000000  0.047745    0.000000
# 2025-03-11  0.000000  0.040601    0.000000
# 2025-03-12  0.000000  0.022889    0.000000
# 2025-03-13  0.000000  0.017685    0.000000
# 2025-03-14  0.000000  0.009023    0.000000
# 2025-03-15  0.000000  0.003811    0.000000
# 2025-03-16  0.000000  0.006456    0.000000
# 2025-03-17  0.000000  0.006472    0.000000
# 2025-03-18  0.000000  0.006820    0.000000
# 2025-03-19  0.000000  0.012950    0.000000
# 2025-03-20  0.000000  0.007553    0.000000
# 2025-03-21  0.000000  0.005498    0.000000
# 2025-03-22  0.000000  0.002711    0.000000
# 2025-03-23  0.000000  0.003096    0.000000
# 2025-03-24  0.000000  0.008241    0.000000
# 2025-03-25  0.000000  0.006392    0.000000
# 2025-03-26  0.000000  0.006487    0.000000
# 2025-03-27  0.000000  0.004902    0.000000
# 2025-03-28  0.000000  0.011827    0.000000
# 2025-03-29  0.000000  0.009436    0.000000
# 2025-03-30  0.000000  0.010040    0.000000
# 2025-03-31  0.000000  0.012205    0.000000
# 2025-04-01  0.000000  0.009051    0.000000
# 2025-04-02  0.000000  0.016550    0.000000
# 2025-04-03  0.000000  0.014316    0.000000
# 2025-04-04  0.000000  0.014421    0.000000
# 2025-04-05  0.000000  0.004689    0.000000
# 2025-04-06  2.090298  0.073081   26.384922
# 2025-04-07  1.989516  0.122588   73.719698
# 2025-04-08  0.562921  0.041307   69.268670
# 2025-04-09  0.901560  0.073449   29.300764
# 2025-04-10  1.185874  0.041811   93.431304
# 2025-04-11  0.612607  0.018621  100.000000
# 2025-04-12  0.513515  0.015788  100.000000
# 2025-04-13  0.595825  0.018298  100.000000
# 2025-04-14  0.223853  0.006894  100.000000
# ------------------------------------------------------------------
# this position returned 8.47383561514703 in  43  days, for an apr of  71.9290697564806
# a base  position returned 0.8799867235764031 in  43  days, for an apr of  7.46965474663691
# fee in token 1 and token 2 422.9409955364483 0.2687062028586831
# totalFee in USD 846.0017354384414
# Your liquidity was active for: 16.09547344014551
# forecast:  24292.93186117342
# ------------------------------------------------------------------
#                  amountV   feecumsum
# date
# 2025-03-03  10000.000000    0.000000
# 2025-03-04  10000.000000    0.000000
# 2025-03-05  10000.000000    0.000000
# 2025-03-06  10000.000000    0.000000
# 2025-03-07  10000.000000    0.000000
# 2025-03-08  10000.000000    0.000000
# 2025-03-09  10000.000000    0.000000
# 2025-03-10  10000.000000    0.000000
# 2025-03-11  10000.000000    0.000000
# 2025-03-12  10000.000000    0.000000
# 2025-03-13  10000.000000    0.000000
# 2025-03-14  10000.000000    0.000000
# 2025-03-15  10000.000000    0.000000
# 2025-03-16  10000.000000    0.000000
# 2025-03-17  10000.000000    0.000000
# 2025-03-18  10000.000000    0.000000
# 2025-03-19  10000.000000    0.000000
# 2025-03-20  10000.000000    0.000000
# 2025-03-21  10000.000000    0.000000
# 2025-03-22  10000.000000    0.000000
# 2025-03-23  10000.000000    0.000000
# 2025-03-24  10000.000000    0.000000
# 2025-03-25  10000.000000    0.000000
# 2025-03-26  10000.000000    0.000000
# 2025-03-27  10000.000000    0.000000
# 2025-03-28  10000.000000    0.000000
# 2025-03-29  10000.000000    0.000000
# 2025-03-30  10000.000000    0.000000
# 2025-03-31  10000.000000    0.000000
# 2025-04-01  10000.000000    0.000000
# 2025-04-02  10000.000000    0.000000
# 2025-04-03  10000.000000    0.000000
# 2025-04-04  10000.000000    0.000000
# 2025-04-05  10000.000000    0.000000
# 2025-04-06  10000.000000  209.029783
# 2025-04-07   9755.360065  403.114204
# 2025-04-08   9639.279737  457.375766
# 2025-04-09   9186.311113  540.195870
# 2025-04-10   9958.384434  658.289770
# 2025-04-11   9434.381393  716.085434
# 2025-04-12   9713.413066  765.965242
# 2025-04-13   9951.826038  825.260735
# 2025-04-14   9882.749048  847.383562
#                ILnorm     PNLnorm  feecumsumnorm
# date
# 2025-03-03  99.956074   99.956074       0.000000
# 2025-03-04  99.952988   99.952988       0.000000
# 2025-03-05  99.953780   99.953780       0.000000
# 2025-03-06  99.955315   99.955315       0.000000
# 2025-03-07  99.952813   99.952813       0.000000
# 2025-03-08  99.953514   99.953514       0.000000
# 2025-03-09  99.954677   99.954677       0.000000
# 2025-03-10  99.950896   99.950896       0.000000
# 2025-03-11  99.944826   99.944826       0.000000
# 2025-03-12  99.947690   99.947690       0.000000
# 2025-03-13  99.947363   99.947363       0.000000
# 2025-03-14  99.946660   99.946660       0.000000
# 2025-03-15  99.947827   99.947827       0.000000
# 2025-03-16  99.948275   99.948275       0.000000
# 2025-03-17  99.947434   99.947434       0.000000
# 2025-03-18  99.947951   99.947951       0.000000
# 2025-03-19  99.948573   99.948573       0.000000
# 2025-03-20  99.950845   99.950845       0.000000
# 2025-03-21  99.949779   99.949779       0.000000
# 2025-03-22  99.949511   99.949511       0.000000
# 2025-03-23  99.949600   99.949600       0.000000
# 2025-03-24  99.949963   99.949963       0.000000
# 2025-03-25  99.952096   99.952096       0.000000
# 2025-03-26  99.951723   99.951723       0.000000
# 2025-03-27  99.950422   99.950422       0.000000
# 2025-03-28  99.950127   99.950127       0.000000
# 2025-03-29  99.947420   99.947420       0.000000
# 2025-03-30  99.945239   99.945239       0.000000
# 2025-03-31  99.944029   99.944029       0.000000
# 2025-04-01  99.945394   99.945394       0.000000
# 2025-04-02  99.947077   99.947077       0.000000
# 2025-04-03  99.945058   99.945058       0.000000
# 2025-04-04  99.944721   99.944721       0.000000
# 2025-04-05  99.945139   99.945139       0.000000
# 2025-04-06  97.786224   99.876521       2.090298
# 2025-04-07  96.680665  100.711807       4.031142
# 2025-04-08  92.119231   96.692989       4.573758
# 2025-04-09  99.796175  105.198134       5.401959
# 2025-04-10  95.170474  101.753372       6.582898
# 2025-04-11  97.296654  104.457508       7.160854
# 2025-04-12  99.475232  107.134884       7.659652
# 2025-04-13  98.371706  106.624313       8.252607
# 2025-04-14  99.191313  107.665148       8.473836
#           amountV   feecumsum
# 0     9925.340383  847.383562
# 1     9914.309013  845.309747
# 2     9914.584858  843.426401
# 3     9942.045994  841.938969
# 4     9925.867280  840.196674
# ..            ...         ...
# 995  10000.000000    0.000000
# 996  10000.000000    0.000000
# 997  10000.000000    0.000000
# 998  10000.000000    0.000000
# 999  10000.000000    0.000000
#
# [1000 rows x 2 columns]
#          ILnorm     PNLnorm  feecumsumnorm
# 0     99.827447  108.365024       8.537577
# 1     99.830101  108.346784       8.516683
# 2    100.106781  108.604489       8.497708
# 3     99.944106  108.426827       8.482721
# 4    100.078603  108.543770       8.465167
# ..          ...         ...            ...
# 995  100.700216  100.700216       0.000000
# 996  100.699975  100.699975       0.000000
# 997  100.701153  100.701153       0.000000
# 998  100.702232  100.702232       0.000000
# 999    0.000000    0.000000       0.000000
#
# [1000 rows x 3 columns]
# /Users/dmiwu/work/PythonProject/uniswap-v3-backtest-python/charts.py:105: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final3['amountVlast'].iloc[-1]=final3['HODL'].iloc[-1]
